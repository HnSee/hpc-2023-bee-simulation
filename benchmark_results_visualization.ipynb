# %%
import pandas as pd
import json
import matplotlib as mpl
from matplotlib import pyplot as plt, patches

# %%
with open('results.json') as results_file:
    results_json = json.load(results_file)
results = pd.json_normalize(results_json, "benchmarks")
results
# Out:
#                              name  family_index  per_family_instance_index  \
# 0        BM_MultiKeyMatrix_Init/2             0                          0
# 1        BM_MultiKeyMatrix_Init/4             0                          1
# 2        BM_MultiKeyMatrix_Init/8             0                          2
# 3       BM_MultiKeyMatrix_Init/16             0                          3
# 4       BM_MultiKeyMatrix_Init/32             0                          4
# 5       BM_MultiKeyMatrix_Init/64             0                          5
# 6      BM_MultiKeyMatrix_Init/128             0                          6
# 7      BM_MultiKeyMatrix_Init/256             0                          7
# 8      BM_MultiKeyMatrix_Init/512             0                          8
# 9     BM_MultiKeyMatrix_Init/1024             0                          9
# 10    BM_MultiKeyMatrix_Init/2048             0                         10
# 11    BM_MultiKeyMatrix_Init/4096             0                         11
# 12    BM_MultiKeyMatrix_Init/8192             0                         12
# 13   BM_MultiKeyMatrix_Init/16384             0                         13
# 14   BM_MultiKeyMatrix_Init/32768             0                         14
# 15   BM_MultiKeyMatrix_Init/65536             0                         15
# 16  BM_MultiKeyMatrix_Init/131072             0                         16
# 17        BM_MultiKeyMatrix_Get/2             1                          0
# 18        BM_MultiKeyMatrix_Get/4             1                          1
# 19        BM_MultiKeyMatrix_Get/8             1                          2
# 20       BM_MultiKeyMatrix_Get/16             1                          3
# 21       BM_MultiKeyMatrix_Get/32             1                          4
# 22       BM_MultiKeyMatrix_Get/64             1                          5
# 23      BM_MultiKeyMatrix_Get/128             1                          6
# 24      BM_MultiKeyMatrix_Get/256             1                          7
# 25      BM_MultiKeyMatrix_Get/512             1                          8
# 26     BM_MultiKeyMatrix_Get/1024             1                          9
# 27     BM_MultiKeyMatrix_Get/2048             1                         10
# 28     BM_MultiKeyMatrix_Get/4096             1                         11
# 29     BM_MultiKeyMatrix_Get/8192             1                         12
# 30    BM_MultiKeyMatrix_Get/16384             1                         13
# 31    BM_MultiKeyMatrix_Get/32768             1                         14
# 32    BM_MultiKeyMatrix_Get/65536             1                         15
# 33   BM_MultiKeyMatrix_Get/131072             1                         16
#
#                          run_name   run_type  repetitions  repetition_index  \
# 0        BM_MultiKeyMatrix_Init/2  iteration            1                 0
# 1        BM_MultiKeyMatrix_Init/4  iteration            1                 0
# 2        BM_MultiKeyMatrix_Init/8  iteration            1                 0
# 3       BM_MultiKeyMatrix_Init/16  iteration            1                 0
# 4       BM_MultiKeyMatrix_Init/32  iteration            1                 0
# 5       BM_MultiKeyMatrix_Init/64  iteration            1                 0
# 6      BM_MultiKeyMatrix_Init/128  iteration            1                 0
# 7      BM_MultiKeyMatrix_Init/256  iteration            1                 0
# 8      BM_MultiKeyMatrix_Init/512  iteration            1                 0
# 9     BM_MultiKeyMatrix_Init/1024  iteration            1                 0
# 10    BM_MultiKeyMatrix_Init/2048  iteration            1                 0
# 11    BM_MultiKeyMatrix_Init/4096  iteration            1                 0
# 12    BM_MultiKeyMatrix_Init/8192  iteration            1                 0
# 13   BM_MultiKeyMatrix_Init/16384  iteration            1                 0
# 14   BM_MultiKeyMatrix_Init/32768  iteration            1                 0
# 15   BM_MultiKeyMatrix_Init/65536  iteration            1                 0
# 16  BM_MultiKeyMatrix_Init/131072  iteration            1                 0
# 17        BM_MultiKeyMatrix_Get/2  iteration            1                 0
# 18        BM_MultiKeyMatrix_Get/4  iteration            1                 0
# 19        BM_MultiKeyMatrix_Get/8  iteration            1                 0
# 20       BM_MultiKeyMatrix_Get/16  iteration            1                 0
# 21       BM_MultiKeyMatrix_Get/32  iteration            1                 0
# 22       BM_MultiKeyMatrix_Get/64  iteration            1                 0
# 23      BM_MultiKeyMatrix_Get/128  iteration            1                 0
# 24      BM_MultiKeyMatrix_Get/256  iteration            1                 0
# 25      BM_MultiKeyMatrix_Get/512  iteration            1                 0
# 26     BM_MultiKeyMatrix_Get/1024  iteration            1                 0
# 27     BM_MultiKeyMatrix_Get/2048  iteration            1                 0
# 28     BM_MultiKeyMatrix_Get/4096  iteration            1                 0
# 29     BM_MultiKeyMatrix_Get/8192  iteration            1                 0
# 30    BM_MultiKeyMatrix_Get/16384  iteration            1                 0
# 31    BM_MultiKeyMatrix_Get/32768  iteration            1                 0
# 32    BM_MultiKeyMatrix_Get/65536  iteration            1                 0
# 33   BM_MultiKeyMatrix_Get/131072  iteration            1                 0
#
#     threads  iterations     real_time      cpu_time time_unit
# 0         1     3005410    231.897352    231.619384        ns
# 1         1     3047564    228.262591    228.032292        ns
# 2         1     3050206    222.803920    222.695500        ns
# 3         1     3060184    226.814136    226.696622        ns
# 4         1     3078028    225.463149    225.336190        ns
# 5         1     3023209    230.042014    229.905578        ns
# 6         1     2649657    262.849659    262.693180        ns
# 7         1     2528463    281.192733    280.991276        ns
# 8         1     1871346    327.228049    327.006628        ns
# 9         1     1881901    371.950142    371.784014        ns
# 10        1     1305103    519.967055    519.564539        ns
# 11        1      608952   1065.294720   1064.418347        ns
# 12        1      288854   2206.151442   2205.239003        ns
# 13        1      158054   4618.057790   4612.071058        ns
# 14        1       73157   9134.843425   9129.892779        ns
# 15        1       35575  19245.040475  19232.606662        ns
# 16        1       17828  39521.958332  39499.258638        ns
# 17        1      908597    768.647925    765.734624        ns
# 18        1      892135    771.993979    769.316019        ns
# 19        1      893290    771.588862    769.773498        ns
# 20        1      863260    793.196789    790.340165        ns
# 21        1      832323    787.789642    784.647339        ns
# 22        1      854482    798.300533    795.519276        ns
# 23        1      846813    796.765879    794.977530        ns
# 24        1      835034    805.391422    802.935653        ns
# 25        1      831226    812.204622    809.598297        ns
# 26        1      804589    813.918997    810.337815        ns
# 27        1      809131    814.101513    812.437576        ns
# 28        1      778058    830.815166    828.455785        ns
# 29        1      747255    845.346700    843.719823        ns
# 30        1      788496    889.231730    887.953306        ns
# 31        1      759773   1044.700857   1037.484203        ns
# 32        1      716822    986.912199    986.854774        ns
# 33        1      673339   1038.895612   1038.285017        ns

# %%
results["operation"] = results["name"].str.extract(r'_([A-Za-z0-9]+)/')
results["operation"] = results["operation"].str.lower()
results["size"] = results["name"].str.extract(r'/(\d+)').astype(int)
results
# Out:
#                              name  family_index  per_family_instance_index  \
# 0        BM_MultiKeyMatrix_Init/2             0                          0
# 1        BM_MultiKeyMatrix_Init/4             0                          1
# 2        BM_MultiKeyMatrix_Init/8             0                          2
# 3       BM_MultiKeyMatrix_Init/16             0                          3
# 4       BM_MultiKeyMatrix_Init/32             0                          4
# 5       BM_MultiKeyMatrix_Init/64             0                          5
# 6      BM_MultiKeyMatrix_Init/128             0                          6
# 7      BM_MultiKeyMatrix_Init/256             0                          7
# 8      BM_MultiKeyMatrix_Init/512             0                          8
# 9     BM_MultiKeyMatrix_Init/1024             0                          9
# 10    BM_MultiKeyMatrix_Init/2048             0                         10
# 11    BM_MultiKeyMatrix_Init/4096             0                         11
# 12    BM_MultiKeyMatrix_Init/8192             0                         12
# 13   BM_MultiKeyMatrix_Init/16384             0                         13
# 14   BM_MultiKeyMatrix_Init/32768             0                         14
# 15   BM_MultiKeyMatrix_Init/65536             0                         15
# 16  BM_MultiKeyMatrix_Init/131072             0                         16
# 17        BM_MultiKeyMatrix_Get/2             1                          0
# 18        BM_MultiKeyMatrix_Get/4             1                          1
# 19        BM_MultiKeyMatrix_Get/8             1                          2
# 20       BM_MultiKeyMatrix_Get/16             1                          3
# 21       BM_MultiKeyMatrix_Get/32             1                          4
# 22       BM_MultiKeyMatrix_Get/64             1                          5
# 23      BM_MultiKeyMatrix_Get/128             1                          6
# 24      BM_MultiKeyMatrix_Get/256             1                          7
# 25      BM_MultiKeyMatrix_Get/512             1                          8
# 26     BM_MultiKeyMatrix_Get/1024             1                          9
# 27     BM_MultiKeyMatrix_Get/2048             1                         10
# 28     BM_MultiKeyMatrix_Get/4096             1                         11
# 29     BM_MultiKeyMatrix_Get/8192             1                         12
# 30    BM_MultiKeyMatrix_Get/16384             1                         13
# 31    BM_MultiKeyMatrix_Get/32768             1                         14
# 32    BM_MultiKeyMatrix_Get/65536             1                         15
# 33   BM_MultiKeyMatrix_Get/131072             1                         16
#
#                          run_name   run_type  repetitions  repetition_index  \
# 0        BM_MultiKeyMatrix_Init/2  iteration            1                 0
# 1        BM_MultiKeyMatrix_Init/4  iteration            1                 0
# 2        BM_MultiKeyMatrix_Init/8  iteration            1                 0
# 3       BM_MultiKeyMatrix_Init/16  iteration            1                 0
# 4       BM_MultiKeyMatrix_Init/32  iteration            1                 0
# 5       BM_MultiKeyMatrix_Init/64  iteration            1                 0
# 6      BM_MultiKeyMatrix_Init/128  iteration            1                 0
# 7      BM_MultiKeyMatrix_Init/256  iteration            1                 0
# 8      BM_MultiKeyMatrix_Init/512  iteration            1                 0
# 9     BM_MultiKeyMatrix_Init/1024  iteration            1                 0
# 10    BM_MultiKeyMatrix_Init/2048  iteration            1                 0
# 11    BM_MultiKeyMatrix_Init/4096  iteration            1                 0
# 12    BM_MultiKeyMatrix_Init/8192  iteration            1                 0
# 13   BM_MultiKeyMatrix_Init/16384  iteration            1                 0
# 14   BM_MultiKeyMatrix_Init/32768  iteration            1                 0
# 15   BM_MultiKeyMatrix_Init/65536  iteration            1                 0
# 16  BM_MultiKeyMatrix_Init/131072  iteration            1                 0
# 17        BM_MultiKeyMatrix_Get/2  iteration            1                 0
# 18        BM_MultiKeyMatrix_Get/4  iteration            1                 0
# 19        BM_MultiKeyMatrix_Get/8  iteration            1                 0
# 20       BM_MultiKeyMatrix_Get/16  iteration            1                 0
# 21       BM_MultiKeyMatrix_Get/32  iteration            1                 0
# 22       BM_MultiKeyMatrix_Get/64  iteration            1                 0
# 23      BM_MultiKeyMatrix_Get/128  iteration            1                 0
# 24      BM_MultiKeyMatrix_Get/256  iteration            1                 0
# 25      BM_MultiKeyMatrix_Get/512  iteration            1                 0
# 26     BM_MultiKeyMatrix_Get/1024  iteration            1                 0
# 27     BM_MultiKeyMatrix_Get/2048  iteration            1                 0
# 28     BM_MultiKeyMatrix_Get/4096  iteration            1                 0
# 29     BM_MultiKeyMatrix_Get/8192  iteration            1                 0
# 30    BM_MultiKeyMatrix_Get/16384  iteration            1                 0
# 31    BM_MultiKeyMatrix_Get/32768  iteration            1                 0
# 32    BM_MultiKeyMatrix_Get/65536  iteration            1                 0
# 33   BM_MultiKeyMatrix_Get/131072  iteration            1                 0
#
#     threads  iterations     real_time      cpu_time time_unit operation  \
# 0         1     3005410    231.897352    231.619384        ns      init
# 1         1     3047564    228.262591    228.032292        ns      init
# 2         1     3050206    222.803920    222.695500        ns      init
# 3         1     3060184    226.814136    226.696622        ns      init
# 4         1     3078028    225.463149    225.336190        ns      init
# 5         1     3023209    230.042014    229.905578        ns      init
# 6         1     2649657    262.849659    262.693180        ns      init
# 7         1     2528463    281.192733    280.991276        ns      init
# 8         1     1871346    327.228049    327.006628        ns      init
# 9         1     1881901    371.950142    371.784014        ns      init
# 10        1     1305103    519.967055    519.564539        ns      init
# 11        1      608952   1065.294720   1064.418347        ns      init
# 12        1      288854   2206.151442   2205.239003        ns      init
# 13        1      158054   4618.057790   4612.071058        ns      init
# 14        1       73157   9134.843425   9129.892779        ns      init
# 15        1       35575  19245.040475  19232.606662        ns      init
# 16        1       17828  39521.958332  39499.258638        ns      init
# 17        1      908597    768.647925    765.734624        ns       get
# 18        1      892135    771.993979    769.316019        ns       get
# 19        1      893290    771.588862    769.773498        ns       get
# 20        1      863260    793.196789    790.340165        ns       get
# 21        1      832323    787.789642    784.647339        ns       get
# 22        1      854482    798.300533    795.519276        ns       get
# 23        1      846813    796.765879    794.977530        ns       get
# 24        1      835034    805.391422    802.935653        ns       get
# 25        1      831226    812.204622    809.598297        ns       get
# 26        1      804589    813.918997    810.337815        ns       get
# 27        1      809131    814.101513    812.437576        ns       get
# 28        1      778058    830.815166    828.455785        ns       get
# 29        1      747255    845.346700    843.719823        ns       get
# 30        1      788496    889.231730    887.953306        ns       get
# 31        1      759773   1044.700857   1037.484203        ns       get
# 32        1      716822    986.912199    986.854774        ns       get
# 33        1      673339   1038.895612   1038.285017        ns       get
#
#       size
# 0        2
# 1        4
# 2        8
# 3       16
# 4       32
# 5       64
# 6      128
# 7      256
# 8      512
# 9     1024
# 10    2048
# 11    4096
# 12    8192
# 13   16384
# 14   32768
# 15   65536
# 16  131072
# 17       2
# 18       4
# 19       8
# 20      16
# 21      32
# 22      64
# 23     128
# 24     256
# 25     512
# 26    1024
# 27    2048
# 28    4096
# 29    8192
# 30   16384
# 31   32768
# 32   65536
# 33  131072

# %%
times = results[["operation", "real_time", "size"]].pivot(index="size", columns="operation", values="real_time")
times.plot.bar()
plt.xticks(rotation = 45)
plt.xlabel("Size in number of elements")
plt.ylabel("Time in ns")
plt.show()

# %%
from anytree import Node, RenderTree, LevelOrderGroupIter
from anytree.exporter import DotExporter
from IPython.display import Image, display


def generate_label(x, y):
    return "({}|{})".format(x, y)


range_query = pd.read_csv("builddir/rangeSearchTest2.csv")

root = (
    range_query[["x", "y"]]
    .merge(
        range_query[["parent_x", "parent_y"]],
        how="right",
        left_on=["x", "y"],
        right_on=["parent_x", "parent_y"],
    )
    .drop_duplicates()
)
root = root[root["x"].isna()]
root = (root.iloc[0]["parent_x"], root.iloc[0]["parent_y"])
root = Node(generate_label(root[0], root[1]), x=root[0], y=root[1])

nodes = [root]

def get_node(x: float, y: float) -> Node | None:
    for node in nodes:
        if node.x == x and node.y == y:
            return node
    return None

def add_node(x: float, y: float) -> Node:
    existing_node = get_node(x, y)
    if existing_node is not None:
        return existing_node

    if x == root.x and y == root.y:
        newNode = Node(generate_label(x, y), parent=root, x=x, y=y)
        nodes.append(newNode)
        return newNode

    n = range_query[(range_query["x"] == x) & (range_query["y"] == y)].iloc[0]

    for possible_node in nodes:
        if possible_node.x == n["x"] and possible_node.y == n["x"]:
            return possible_node

    parent = add_node(n["parent_x"], n["parent_y"])

    newNode = Node(generate_label(x, y), parent=parent, x=x, y=y)
    nodes.append(newNode)
    return newNode


for _, row in range_query.iterrows():
    add_node(row["x"], row["y"])

DotExporter(root).to_picture("asd.png")
display(Image(filename="asd.png"))

fig, ax = plt.subplots()
ax.set_aspect("equal")

currentlyX = True
x_level = 0
y_level = 0
max_level = root.height / 2

range_circle = plt.Circle((15, 70), 40, color="y", alpha=0.5)
ax.add_patch(range_circle)

for node_group in LevelOrderGroupIter(root):
    if currentlyX:
        current_color=mpl.colormaps["Blues"](1 - x_level / max_level)
        for node in node_group:
            ax.plot(node.x, node.y, "o", color=current_color)
        x_level = x_level + 1
    else:
        current_color=mpl.colormaps["Reds"](1 - y_level / max_level)
        for node in node_group:
            ax.plot(node.x, node.y, "o", color=current_color)
        y_level = y_level + 1

    currentlyX = not currentlyX

# %%
df_chunks = pd.read_csv("builddir/chunks.csv", index_col="id")
df_chunks

fig, ax = plt.subplots()

for i, r in df_chunks.iterrows():
    width = r["xmax"] - r["xmin"]
    height = r["ymax"] - r["ymin"]
    rectangle = patches.Rectangle((r["xmin"], r["ymin"]), width, height, color="C{}".format(i))
    rx, ry = rectangle.get_xy()
    cx = rx + rectangle.get_width() / 2.0
    cy = ry + rectangle.get_height() / 2.0
    ax.add_patch(rectangle)
    ax.annotate(i, (cx, cy), ha="center", va="center")

plt.xlim(0, 10000)
plt.ylim(0, 5000)
# Out:
# (0.0, 5000.0)
